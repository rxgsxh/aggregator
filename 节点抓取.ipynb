# %% [markdown]
# <a href="https://colab.research.google.com/github/rxgsxh/aggregator/blob/main/%E8%8A%82%E7%82%B9%E6%8A%93%E5%8F%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/rxgsxh/aggregator.git
# Out:
# Cloning into 'aggregator'...
# remote: Enumerating objects: 2682, done.
# remote: Total 2682 (delta 0), reused 0 (delta 0), pack-reused 2682 (from 1)
# Receiving objects: 100% (2682/2682), 535.10 MiB | 20.45 MiB/s, done.
# Resolving deltas: 100% (1637/1637), done.
# Updating files: 100% (483/483), done.

# %%
# %cd aggregator
# Out:
# /content/aggregator

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 kB 6.0 MB/s eta 0:00:00
# ...
#   Created wheel for fofa-hack: filename=fofa_hack-2.5.2-py3-none-any.whl size=31469 sha256=4b72d57a80d573ccfd3da7c6adfef77b196525958e83fd5c3cf4c9c38774e345
#   Stored in directory: /root/.cache/pip/wheels/be/24/dd/2a217b13b9f502c53f1c1212b2025abb144311371b77f848b3
# Successfully built fofa-hack
# ...

# %%
# !python -u subscribe/collect.py -s
# Out:
# 2025-04-07 12:56:02 collect.py [line:205] ERROR: cannot extract username and gist id due to invalid github gist link
# 2025-04-07 12:56:02 collect.py [line:68] INFO: start checking whether existing subscriptions have expired
# 2025-04-07 12:56:02 collect.py [line:110] INFO: load exists subscription finished, count: 0
# 2025-04-07 12:56:02 crawl.py [line:1430] INFO: [TelegramCrawl] starting crawl from telegram, channel: jichang_list, pages: 207
# 2025-04-07 12:56:02 crawl.py [line:1390] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4122
# 2025-04-07 12:56:02 crawl.py [line:1390] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4102
# 2025-04-07 12:56:02 crawl.py [line:1390] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4082
# 2025-04-07 12:56:02 crawl.py [line:1390] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4062
# ...

# %%
from google.colab import files
files.download('/content/aggregator/data/v2ray.txt')

# %%
from google.colab import files
files.download('/content/aggregator/data/clash.yaml')

# %%
from google.colab import files
files.download('/content/aggregator/data/singbox.json')
